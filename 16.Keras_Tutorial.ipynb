# %% [markdown]
# # Keras深度學習初體驗
# 利用keras套件，產生一個32個神經元的深度學習模型進行訓練

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ## 隨機產生1000筆資料，用來做為訓練資料
# ## 每筆資料包含十個float數字, 跟一個相對應的標籤(label)

# %%
import numpy as np
#隨機產生1000筆資料，每筆資料包含十個float數字
data = np.random.random((1000, 10)) 
#隨機產生1000筆資料作為標籤，每筆資料上限為2(意思就是0 或 1)
labels = np.random.randint(2, size=(1000, 1)) 
print(np.shape(data))
print(data[0])
print(np.shape(labels))
print(labels[0])
# Out:
# (1000, 10)
# [0.09874619 0.41168398 0.30583257 0.32863192 0.57407891 0.65380283
#  0.27358893 0.7138232  0.62541646 0.41596865]
# (1000, 1)
# [0]

# %% [markdown]
# ## 步驟一：定義學習模型模型

# %%
#定義模型為一層一層堆疊模式
model = Sequential()
#定義第一層為32個神經元，輸入資料的維度為10，門檻函數為relu
model.add(Dense(32, activation='relu', input_dim=10))
#定義第二層為1個神經元的輸出層，門檻函數為sigmoid
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## 步驟二：定義評估函數

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 步驟三：重複計算並調整模型

# %%
#將測試資料data，與相對應的結果(標籤)，丟進模型進行訓練
#1000筆資料每次同時以32筆進行訓練，直到1000筆資料結束為止
#總共要訓練10次(epochs)
model.fit(data, labels, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 1ms/step - loss: 0.7013 - accuracy: 0.4740
# Epoch 2/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6939 - accuracy: 0.5281
# Epoch 3/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6960 - accuracy: 0.4793
# Epoch 4/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.5376
# Epoch 5/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6920 - accuracy: 0.5567
# Epoch 6/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6947 - accuracy: 0.5275
# Epoch 7/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6936 - accuracy: 0.5429
# Epoch 8/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6914 - accuracy: 0.5570
# Epoch 9/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6868 - accuracy: 0.5619
# Epoch 10/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6901 - accuracy: 0.5439

# %% [markdown]
# ## 把測試資料丟入觀看評估結果

# %%
#本範例將訓練資料作為測試資料進行評估
#score[0]為誤差值，score[1]為正確性
score=model.evaluate(data, labels)
print(score[1])
# Out:
# 32/32 [==============================] - 0s 989us/step - loss: 0.6880 - accuracy: 0.5430
# 0.5429999828338623
